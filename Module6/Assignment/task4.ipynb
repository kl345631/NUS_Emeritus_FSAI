# %% [markdown]
# task4: Functions

# %%
length = int(input("Enter length: "))
width = int(input("Enter width: "))

# %%
def results():
    area = length * width
    print(f'The area of rectangle is: {area}')

# %%
results()
