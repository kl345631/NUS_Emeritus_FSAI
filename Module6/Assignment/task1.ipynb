# %% [markdown]
# task 1: Variables and Data Types

# %%
name = input("Please enter Name: ")
age = int(input("Please enter Age: "))
height = float(input("Please Height: "))

# %%
print(f"Hello {name}")
